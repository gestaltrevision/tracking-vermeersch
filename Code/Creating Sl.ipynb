# %%
from ut_video_seg import *
from pathlib import Path, PureWindowsPath

# %%
video_name="2vre55a"
data_dir="C:/Users/jeuux/Desktop/Carrera/MoAI/TFM/AnnotatedData"
video_path="C:/Users/jeuux/Desktop/Carrera/MoAI/TFM/Data/2vre55a/segments/1/fullstream.mp4"
frames_folder=os.path.join(data_dir,"Sl_Dataset",video_name)

# %%
video = cv2.VideoCapture(video_path)
total = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
fps=video.get(cv2.CAP_PROP_FPS)
video.release()

# %%
video_to_sl(video_path,video_name,frames_folder)
# Out:
# 2vre55afr0.jpg saved successfully
# 2vre55afr3.jpg saved successfully
# 2vre55afr6.jpg saved successfully
# 2vre55afr9.jpg saved successfully
# 2vre55afr12.jpg saved successfully
# 2vre55afr15.jpg saved successfully
# 2vre55afr18.jpg saved successfully
# 2vre55afr21.jpg saved successfully
# 2vre55afr24.jpg saved successfully
# 2vre55afr27.jpg saved successfully
# 2vre55afr30.jpg saved successfully
# 2vre55afr33.jpg saved successfully
# 2vre55afr36.jpg saved successfully
# 2vre55afr39.jpg saved successfully
# 2vre55afr42.jpg saved successfully
# 2vre55afr45.jpg saved successfully
# 2vre55afr48.jpg saved successfully
# 2vre55afr51.jpg saved successfully
# 2vre55afr54.jpg saved successfully
# 2vre55afr57.jpg saved successfully
# 2vre55afr60.jpg saved successfully
# 2vre55afr63.jpg saved successfully
# 2vre55afr66.jpg saved successfully
# 2vre55afr69.jpg saved successfully
# 2vre55afr72.jpg saved successfully
# 2vre55afr75.jpg saved successfully
# 2vre55afr78.jpg saved successfully
# ...

# %%
import torch

# %%
a=torch.tensor([1,2,3])

# %%
b=torch.max(a)
