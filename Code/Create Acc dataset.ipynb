# %%
from acc_ut import *

# %%
acc_path="C:\\Users\\jeuux\\Desktop\\Carrera\\MoAI\\TFM\\AnnotatedData\\Accelerometer_Data"
base_name="Acc_data"

# %%
df_path="C:\\Users\\jeuux\\Desktop\\Carrera\\MoAI\\TFM\\AnnotatedData\\Accelerometer_Data\\Participants\\0605b\\acc_data_0605b.csv"
df=pd.read_csv(df_path)
df
# Out:
#          time   AccX    AccY   AccZ
# 0           0  0.745  -8.172  1.294
# 1          10  0.706  -8.152  1.410
# 2          20  0.745  -8.113  1.403
# 3          30  0.863  -8.009  1.544
# 4          40  0.902  -9.943  1.692
# 5          50 -0.980  -8.066  1.674
# 6          60 -0.862  -8.102  1.919
# 7          70 -0.784  -8.147  1.887
# 8          80 -0.745  -8.275  2.069
# 9          90 -0.666  -8.345  2.121
# 10        100 -0.745  -8.338  2.160
# 11        110 -0.823  -8.252  2.424
# 12        120 -0.902  -8.298  2.392
# 13        130 -0.941  -8.329  2.437
# 14        140  0.902  -8.270  2.546
# 15        150  0.784  -8.309  2.553
# 16        160  0.588  -8.193  2.533
# 17        170  0.510  -8.123  2.480
# 18        180  0.432  -8.045  2.467
# 19        190  0.392  -8.020  2.383
# 20        200  0.353  -9.961  2.492
# 21        210  0.353 -10.000  2.499
# 22        220  0.392  -8.123  2.480
# 23        230  0.392  -8.161  2.487
# 24        240  0.432  -8.200  2.494
# ...

# %%
create_acc_table(acc_path,base_name)
# Out:
# C:\Users\jeuux\Desktop\Carrera\MoAI\TFM\tracking-vermeersch\Code\acc_ut.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df["Recording timestamp"]=df.apply(lambda row: row["Recording timestamp"]-time_offset,axis=1)
# C:\Users\jeuux\Desktop\Carrera\MoAI\TFM\tracking-vermeersch\Code\acc_ut.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df["Recording timestamp"]=fix_frequency(np.asarray(df["Recording timestamp"]))
# ...

# %%
table_path="C:\\Users\\jeuux\\Desktop\\Carrera\\MoAI\\TFM\\AnnotatedData\\Accelerometer_Data\\Acc_data_train.csv"
df=pd.read_csv(table_path)

# %%
df
# Out:
#     participant  start time     feat0  feat1  feat2  feat3  feat4      feat5  \
# 0         0605b         0.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 1         0605b         2.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 2         0605b         4.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 3         0605b         6.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 4         0605b         8.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 5         0605b        10.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 6         0605b        12.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 7         0605b        14.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 8         0605b        16.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 9         0605b        18.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# 10        0605b        22.0  0.497512    0.0    0.0    0.0    0.0  154289.69
# ...
